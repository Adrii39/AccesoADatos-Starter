# %% [markdown]
# # Ex1 - Getting and knowing your Data

# %% [markdown]
# ### Step 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ###  Step 2. Download the dataset to your computer and unzip it.

# %%
import pandas as pd

# %% [markdown]
# ### Step 3. Use the tsv file and assign it to a dataframe called food

# %%
food = pd.read_csv("food_100.csv", sep=",")

# %%
food
# Out:
#     Unnamed: 0   code                                                url  \
# 0            0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1            1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2            2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3            3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4            4  16094  http://world-en.openfoodfacts.org/product/0000...
# ..         ...    ...                                                ...
# 95          95  34715  http://world-en.openfoodfacts.org/product/0000...
# 96          96  34784  http://world-en.openfoodfacts.org/product/0000...
# 97          97  34791  http://world-en.openfoodfacts.org/product/0000...
# 98          98  35071  http://world-en.openfoodfacts.org/product/0000...
# 99          99  35170  http://world-en.openfoodfacts.org/product/0000...
#
#                        creator   created_t      created_datetime  \
# ...

# %% [markdown]
# ### Step 4. See the first 5 entries

# %%
food.head(5) ### Muestra las primeras 5 filas
# Out:
#    Unnamed: 0   code                                                url  \
# 0           0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1           1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2           2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3           3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4           4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#    last_modified_t last_modified_datetime                    product_name  \
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
food.info() ### Nos da informacion del dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Columns: 164 entries, Unnamed: 0 to water-hardness_100g
# dtypes: float64(125), int64(4), object(35)
# memory usage: 128.3+ KB

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Columns: 164 entries, Unnamed: 0 to water-hardness_100g
# dtypes: float64(125), int64(4), object(35)
# memory usage: 128.3+ KB

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
for x in food.columns:
    print(x)
# Out:
# Unnamed: 0
# code
# url
# creator
# created_t
# created_datetime
# last_modified_t
# last_modified_datetime
# product_name
# generic_name
# quantity
# packaging
# packaging_tags
# brands
# brands_tags
# categories
# categories_tags
# categories_en
# origins
# origins_tags
# manufacturing_places
# manufacturing_places_tags
# labels
# labels_tags
# labels_en
# emb_codes
# emb_codes_tags
# first_packaging_code_geo
# cities
# cities_tags
# purchase_places
# stores
# countries
# countries_tags
# countries_en
# ingredients_text
# allergens
# allergens_en
# traces
# traces_tags
# traces_en
# serving_size
# no_nutriments
# additives_n
# additives
# additives_tags
# additives_en
# ingredients_from_palm_oil_n
# ingredients_from_palm_oil
# ingredients_from_palm_oil_tags
# ingredients_that_may_be_from_palm_oil_n
# ingredients_that_may_be_from_palm_oil
# ingredients_that_may_be_from_palm_oil_tags
# nutrition_grade_uk
# nutrition_grade_fr
# pnns_groups_1
# pnns_groups_2
# states
# states_tags
# ...

# %%
food.columns ### Nos da las columnas del dataframe
# Out:
# Index(['Unnamed: 0', 'code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=164)

# %% [markdown]
# ### Step 8. What is the name of 105th column?

# %%
food.loc[[95]] ### Nos da la fila 95
# Out:
#     Unnamed: 0   code                                                url  \
# 95          95  34715  http://world-en.openfoodfacts.org/product/0000...
#
#             creator   created_t      created_datetime  last_modified_t  \
# 95  usda-ndb-import  1489055715  2017-03-09T10:35:15Z       1489055715
#
#    last_modified_datetime          product_name  generic_name  ...  \
# 95   2017-03-09T10:35:15Z  Organic Pecan Halves           NaN  ...
#
#    fruits-vegetables-nuts_100g fruits-vegetables-nuts-estimate_100g  \
# 95                         NaN                                  NaN
#
#    collagen-meat-protein-ratio_100g cocoa_100g chlorophyl_100g  \
# 95                              NaN        NaN             NaN
#
#    carbon-footprint_100g nutrition-score-fr_100g nutrition-score-uk_100g  \
# 95                   NaN                     NaN                     NaN
#
#     glycemic-index_100g  water-hardness_100g
# 95                  NaN                  NaN
#
# ...

# %% [markdown]
# ### Step 9. What is the type of the observations of the 105th column?

# %%
food.info(95)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 164 columns):
#  #    Column                                      Dtype
# ---   ------                                      -----
#  0    Unnamed: 0                                  int64
#  1    code                                        int64
#  2    url                                         object
#  3    creator                                     object
#  4    created_t                                   int64
#  5    created_datetime                            object
#  6    last_modified_t                             int64
#  7    last_modified_datetime                      object
#  8    product_name                                object
#  9    generic_name                                float64
#  10   quantity                                    object
#  11   packaging                                   object
#  12   packaging_tags                              object
# ...

# %% [markdown]
# ### Step 10. How is the dataset indexed?

# %%
print(food.index) ### Nos da el indice del dataframe
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %% [markdown]
# ### Step 11. What is the product name of the 19th observation?

# %%
print(food.loc[18, "product_name"]) ### Nos da el nombre del producto en la fila 18
# Out:
# Lotus Organic Brown Jasmine Rice

# %%
food.product_name[18] ### Nos da el nombre del producto en la fila 18
# Out:
# 'Lotus Organic Brown Jasmine Rice'

# %%
# Out:
# 'Lotus Organic Brown Jasmine Rice'
